# %%
# %load_ext autoreload
# %autoreload 2

# %%
from __future__ import absolute_import, print_function, division
from builtins import *
import time
import math
from collections import OrderedDict
import numpy as np
from pycuda import driver, compiler, gpuarray, tools
import os
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
os.environ['CUDA_DEVICE'] = '1' # pick your device

# -- initialize the device
import pycuda.autoinit

# %%
n_color = 3
power = 5
edge_n_pixels = 2**power
hidden_sizes = [3, 12, 48, 48, 48]
output_sizes = [1]*power

heat_map_edge = 16

# %%
import re
import pandas as pd

datapath = '/media/sdb/PVM_full_set_raw/'
filelist = os.listdir(datapath)

# nparrayfile = re.compile('(.+?)\.npy')
# csvfile = re.compile('(.+?)\.csv')
testfile_exp = re.compile('.+?test.+?')

test_data = {}
train_data = {}
did_it = []
for filename in filelist:
    filename_wo_ext = filename.rsplit('.', 1)[0]
    if filename_wo_ext not in did_it:
        fname = datapath + filename_wo_ext
        arr = np.load(fname + '.npy')
        df = pd.read_csv(fname + '.csv')

        if testfile_exp.match(filename) is None:
            train_data[filename_wo_ext] = (arr, df)
        else:
            test_data[filename_wo_ext] = (arr, df)
        did_it.append(filename_wo_ext)

# %%
from FormattingFiles import norm_and_heatmap#, flatten_image, unflatten_image
from FormattingFiles import fractal_flatten_image, fractal_unflatten_image
from RectangularGridConstructor import shape_check

# %%
heat_map_edges = (heat_map_edge, heat_map_edge)
input_layer_dim = (edge_n_pixels, edge_n_pixels)
# train_data_reformat = {}
train_data_reformat_nontracker = {}
for key, data_and_label in train_data.items():
    data_arr, df = data_and_label
    
    rescale_arr, ground_truth_heat_map_list = norm_and_heatmap(data_arr, df, heat_map_edges,
                                                               input_layer_dim, norm=255.)

#     train_data_reformat[key] = (rescale_arr, ground_truth_heat_map_list)
    train_data_reformat_nontracker[key] = rescale_arr
del train_data

# %%
heat_map_edges = (heat_map_edge, heat_map_edge)
input_layer_dim = (edge_n_pixels, edge_n_pixels)
test_data_reformat = {}
for key, data_and_label in test_data.items():
    data_arr, df = data_and_label
    
    rescale_arr, ground_truth_heat_map_list = norm_and_heatmap(data_arr, df, heat_map_edges,
                                                               input_layer_dim, norm=255.)

    test_data_reformat[key] = (rescale_arr, ground_truth_heat_map_list)
del test_data

# %%
import PVM_PyCUDA
from FractalConstructor import fractal_connections

# %%
connect_dict = fractal_connections(power, n_color, hidden_sizes, output_sizes, context_from_top_0_0=True)

# %%
# dim is a tuple (height, width, number of colors)
dim = (edge_n_pixels, edge_n_pixels, 3)
basic_index = np.arange(np.prod(dim)).reshape(dim)
flat_map = fractal_flatten_image(basic_index)
rev_flat_map = fractal_unflatten_image(basic_index.flatten(), dim)

# %%
saccadePVM = PVM_PyCUDA.PinholeSaccadicPVM(connect_dict, flat_map, rev_flat_map, dim,
                                           x_w=1, y_w=1, omega=0.8, gamma=0.9)

# %%
fname = './SaccadeFullSetTraining/FoveatedFractal_power_of_5_learning_rate_0.01_hidden_3_12_48_48_48_1000000steps'
saccadePVM.load_parameters(fname)

# %%
learning_rate_list = [.01] * 10000000
fname = './SaccadeFullSetTraining/FoveatedFractal_power_of_5_learning_rate_0.01_hidden_3_12_48_48_48_11000000steps'
saccadePVM.train(train_data_reformat_nontracker, learning_rate_list, print_every=100000,
              save_every_print=True, filename=fname, interval=100000)
# Out:
# --------------------------------------------------------------------------------
#                    AVG MSE over last 100000 frames
#     100000 frames: 17.5302491292
#     200000 frames: 19.1183201615
#     300000 frames: 20.0390258875
#     400000 frames: 21.0278286937
#     500000 frames: 21.5808650211
#     600000 frames: 22.3668190711
#     700000 frames: 23.5718669946
#     800000 frames: 24.3225684903
#     900000 frames: 25.4451281608
#    1000000 frames: 26.5039768229
#    1100000 frames: 27.418583636
#    1200000 frames: 28.0810138964
#    1300000 frames: 28.632388456
#    1400000 frames: 29.6888914738
#    1500000 frames: 30.6008739933
#    1600000 frames: 30.5167716012
#    1700000 frames: 31.7403214474
#    1800000 frames: 32.943953931
#    1900000 frames: 34.2865849583
#    2000000 frames: 34.3249990621
#    2100000 frames: 35.4142868123
#    2200000 frames: 37.3676557213
#    2300000 frames: 37.1676481579
#    2400000 frames: 38.1190647609
#    2500000 frames: 39.314401365
#    2600000 frames: 40.0515207242
#    2700000 frames: 40.2191702799
#    2800000 frames: 41.6628045726
#    2900000 frames: 42.7780870278
#    3000000 frames: 43.5684416647
#    3100000 frames: 43.7612884637
#    3200000 frames: 46.1403793036
#    3300000 frames: 46.5914482841
#    3400000 frames: 48.7985009475
#    3500000 frames: 48.3500173046
# PVM_PyCUDA.py:1523: RuntimeWarning: overflow encountered in double_scalars
#   self.ideal_pred.get()) ** 2)
# PVM_PyCUDA.py:1523: RuntimeWarning: overflow encountered in square
#   self.ideal_pred.get()) ** 2)
#    3600000 frames:        nan
#    3700000 frames:        nan
#    3800000 frames:        nan
#    3900000 frames:        nan
#    4000000 frames:        nan
#    4100000 frames:        nan
#    4200000 frames:        nan
#    4300000 frames:        nan
#    4400000 frames:        nan
#    4500000 frames:        nan
#    4600000 frames:        nan
#    4700000 frames:        nan
#    4800000 frames:        nan
#    4900000 frames:        nan
#    5000000 frames:        nan
#    5100000 frames:        nan
#    5200000 frames:        nan
#    5300000 frames:        nan
#    5400000 frames:        nan
#    5500000 frames:        nan
#    5600000 frames:        nan
#    5700000 frames:        nan
#    5800000 frames:        nan
#    5900000 frames:        nan
#    6000000 frames:        nan
#    6100000 frames:        nan
#    6200000 frames:        nan
#    6300000 frames:        nan
#    6400000 frames:        nan
#    6500000 frames:        nan
#    6600000 frames:        nan
#    6700000 frames:        nan
#    6800000 frames:        nan
#    6900000 frames:        nan
#    7000000 frames:        nan
#    7100000 frames:        nan
#    7200000 frames:        nan
#    7300000 frames:        nan
#    7400000 frames:        nan
#    7500000 frames:        nan
#    7600000 frames:        nan
#    7700000 frames:        nan
#    7800000 frames:        nan
#    7900000 frames:        nan
#    8000000 frames:        nan
#    8100000 frames:        nan
#    8200000 frames:        nan
#    8300000 frames:        nan
#    8400000 frames:        nan
#    8500000 frames:        nan
#    8600000 frames:        nan

# %%
# %matplotlib notebook 

# for the differential equation x'' + 2 * gamma * omega * x' + omega**2 (x - x^{eq}) = 0

fig = plt.figure(figsize=(15, 5))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)
# ax4 = fig.add_subplot(224)

unflattened_idx_array = rev_flat_map

# def window_sum(arr, width, height):
#     N_rows, N_cols, n_colors = arr.shape
#     N_s_row = N_rows - height + 1
#     N_s_col = N_cols - width + 1
#     summed_arr = np.zeros((N_s_row, N_s_col))
#     for row in xrange(N_s_row):
#         for col in xrange(N_s_col):
#             summed_arr[row, col] = np.sum(arr[row:row + height,
#                                               col:col + width, :])
#     return summed_arr
L_y = saccadePVM.sub_frame_height
L_x  = saccadePVM.sub_frame_width

def gen_func():
    global test_data_reformat, saccadePVM
    for key, data in test_data_reformat.items():
        rescale_arr, ground_truth_heat_map_list = data
        n_frame, height, width, n_colors = rescale_arr.shape
        
        saccadePVM.reset_state(x_pos=(width - saccadePVM.sub_frame_width) // 2,
                               y_pos=(height - saccadePVM.sub_frame_height) // 2)
        for i in range(n_frame):
            image = rescale_arr[i, ...]
            saccadePVM.forward(image)
            yield image, saccadePVM.pred[:saccadePVM.L_input].get(),\
                saccadePVM.err[:saccadePVM.L_input].get(), saccadePVM.x,\
                saccadePVM.y
                
def update(vals):
    global L_y, L_x
    image, pred, err, x, y = vals
    reordered_err = err[unflattened_idx_array]
    mag_err = abs(reordered_err - 0.5)
    
    im1 = ax1.imshow(image, animated=True)
    ln1.set_xdata([x, x])
    ln1.set_ydata([y, y + L_y])
    ln2.set_xdata([x + L_x, x + L_x])
    ln2.set_ydata([y, y + L_y])
    ln3.set_xdata([x, x + L_x])
    ln3.set_ydata([y, y])
    ln4.set_xdata([x, x + L_x])
    ln4.set_ydata([y + L_y, y + L_y])
        
        
    im2 = ax2.imshow(pred[unflattened_idx_array], animated=True)

    im3 = ax3.imshow(mag_err, animated=True)

#     im4 = ax4.imshow(heatmap.reshape(heat_map_edges),
#                      vmin=0, vmax=1, cmap='gray', animated=True)
    return im1, im2, im3, ln1, ln2, ln3, ln4

vals = gen_func().next()
image, pred, err, x, y = vals
reordered_err = err[unflattened_idx_array]
mag_err = abs(reordered_err - 0.5)

im1 = ax1.imshow(image, animated=True)
ln1, = ax1.plot([x, x], [y, y + L_y], 'r')
ln2, = ax1.plot([x + L_x, x + L_x], [y, y + L_y], 'r')
ln3, = ax1.plot([x, x + L_x], [y, y], 'r')
ln4, = ax1.plot([x, x + L_x], [y + L_y, y + L_y], 'r')



im2 = ax2.imshow(pred[unflattened_idx_array], animated=True)

im3 = ax3.imshow(mag_err, animated=True)

# im4 = ax4.imshow(heatmap.reshape(heat_map_edges),
#                  vmin=0, vmax=1, cmap='gray', animated=True)
ani = animation.FuncAnimation(fig, update, frames=gen_func,
                              interval=5, blit=True, save_count=30*(10*60))

# ani.save('PinholeSaccadicPVM_on_Full_test_gamma_0.9_omega_0.8_structure_16_8_4_3_2_1_input_32_by_32_pvm_unit_in_2_by_2_learning_rate_0.01_hidden_8_3000000steps.mp4',
#          writer='ffmpeg', fps=30, bitrate=-1,
#          extra_args=['-vcodec', 'libx264'])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
saccadePVM.input_frame_rev_shuf

# %%
saccadePVM.L_input

# %%
isinstance(round(1.5), int)

# %%
for key, data in train_data_reformat_nontracker.items():
    frames, rows, cols, n_colors = data.shape
    saccadePVM.reset_state()
    for i in range(frames):
#         saccadePVM.forward(data[i, ...])
        saccadePVM._PinholeSaccadicPVM__backward(data[i, ...], data[i+1, ...], 0.01)
        break
    break
